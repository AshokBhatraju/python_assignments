# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from numpy.linalg import *
from pylab import *
from numpy import *
from numpy.random import *
from scipy.cluster.vq import *
from sklearn.preprocessing import MinMaxScaler

# %%
#Q1

#x1+x2 = 10000
#1.02x1+1.04x2 = 10250
#Convert to matrix equation
# A*X = y = (10000,10250)
#Solve for A


A =np.array([[1,1],[1.02, 1.04]])
y = np.array([[10000],[10250]])
print(solve(A,y))
# Out:
# [[7500.]
#  [2500.]]

# %%
df = pd.read_csv('C://Users/ashok/Desktop/UIC/spring 2020/python 400/assign 6//Assignment7_4.csv')
df.columns=['x','y']

# %%
#plotting Histograms
plt.hist(df['x'],bins=50,rwidth=.80,color='green')
plt.show();

# %%
plt.hist(df['y'],bins=50,rwidth=0.80,color='green')
plt.show();

# %%
#clustering
#k=2
random_state = 0


#Classify points. Adjust n_clusters using graph
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(df)


plt.figure()

plt.scatter(df['x'],df['y'],c=y_pred)
plt.title("Clusters")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#k=3
random_state = 0


#Classify points. Adjust n_clusters using graph
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(df)


plt.figure()

plt.scatter(df['x'],df['y'],c=y_pred)
plt.title("Clusters")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#k=4
random_state = 0


#Classify points. Adjust n_clusters using graph
y_pred = KMeans(n_clusters=4, random_state=random_state).fit_predict(df)


plt.figure()

plt.scatter(df['x'],df['y'],c=y_pred)
plt.title("Clusters")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#K=5
random_state = 0


#Classify points. Adjust n_clusters using graph
y_pred = KMeans(n_clusters=5, random_state=random_state).fit_predict(df)


plt.figure()

plt.scatter(df['x'],df['y'],c=y_pred)
plt.title("Clusters")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
#optimal K value
mms = MinMaxScaler()
mms.fit(df)
data_transformed = mms.transform(df)

# %%
Sum_of_squared_distances = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
print('To determine the optimal number of clusters, we have to select the value of k at the “elbow” ie the point after which the distortion/inertia start decreasing in a linear fashion. Thus for the given data, we conclude that the optimal number of clusters for the data is 3')
# Out:
# To determine the optimal number of clusters, we have to select the value of k at the “elbow” ie the point after which the distortion/inertia start decreasing in a linear fashion. Thus for the given data, we conclude that the optimal number of clusters for the data is 3
